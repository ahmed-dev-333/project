# %% [markdown]
# # Inheritance

# %%
class Grandfather:
    def house(self):
        print("owns a house")
class Father(Grandfather):
    def car(self):
        print("owns a car")
class Son(Father):
    def bike(self):
        print("owns a bike")
class Grandson(Son):
    def cycle(self):
        print("owns a cycle")

g =Grandson()
print("Grandson can access every class")
g.house()
g.car()
g.bike()
g.cycle()
# Out:
# Grandson can access every class
# owns a house
# owns a car
# owns a bike
# owns a cycle

# %%
class Father:
    def house(self):
        print("owns a BROWN house")
class Mother:
    def house(self):
        print("owns a BLUE house")
class Son(Father, Mother):
    def show_house(self):
        print("Son owns both the houses")
        Father.house(self)
        Mother.house(self)
        
h = Son()

h.show_house()
# Out:
# Son owns both the houses
# owns a BROWN house
# owns a BLUE house

# %% [markdown]
# # Composition

# %%
# Inheritance without inheritance

pass

# %%
class Bank_acc:
    def __init__(self, initial_balance):
        self.__balance = initial_balance   # private variable

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print("Amount Deposited:", amount)
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount")
        elif amount > self.__balance:
            print("Insufficient funds")
        else:
            self.__balance -= amount
            print("Amount Withdrawn:", amount ,"Remaining balance:",self.__balance)
            

    def check_balance(self):
        print("Current Balance:", self.__balance)


# Create account
a = Bank_acc(0)

a.deposit(500)
a.withdraw(300)
a.check_balance()
# Out:
# Amount Deposited: 500
# Amount Withdrawn: 300 Remaining balance: 200
# Current Balance: 200
